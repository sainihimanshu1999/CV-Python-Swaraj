# %%
#CARD GAME
#Patte pe Patta- Card on Card

# %%
#52 cards in a deck of cards
# 13 cards each of every suits
# clubs (♣), diamonds (♦), hearts (♥), and spades (♠)
# ace, king, queen, jack, 10, 9, 8, 7, 6, 5, 4, 3, 2

# %%
# rules of the game

'''
1. This game involves two players and initialy each player is given 26 cards each.
2. They have to put there top card on the table turn wise
3. If the card they are going to put on table matchs with the already top card on the table
MATCH condition - Two cards match if they have same suit OR if they have same rank
4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he
already have.
5. This way game runs until one of the player run out of cards
6. The player that run out of cards losses and other player wins the game!!!!!
'''
# Out:
# '\n1. This game involves two players and initialy each player is given 26 cards each.\n2. They have to put there top card on the table turn wise\n3. If the card they are going to put on table matchs with the already top card on the table\nMATCH condition - Two cards match if they have same suit OR if they have same rank\n4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he\nalready have.\n5. This way game runs until one of the player run out of cards\n6. The player that run out of cards losses and other player wins the game!!!!!\n'

# %%
#For this we need to build for classes

#1 . Card class - Hold the information about the card

#2 . Deck class - Hold the information about the complete set of 52 cards

#3 . Player class - Hold the information about the cards the player are having

#4 . Table class - Holds the information about the cards on table.

# %%
import random

suits = ('Hearts','Diamonds','Spades','Clubs')

ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')

values = {'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10,'Ace':11}

# %%
#CARD CLASS

# this class will hold the information about a particular card

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit           # identity of a card
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit     #returns a string defining the card

# %%
a = Card('Hearts','Ten')

# %%
print(a)
# Out:
# Ten of Hearts

# %%
# DECK CLASS

# This class contains the information about the set of 52 cards and each card the object of perviously defined class

# %%
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    
                
    def __str__(self):
        deck_comp = ''
        
        for card in self.deck:
            deck_comp = '\n'+card.__str__()
        
        return 'The deck has :'+ deck_comp
    
    
    def shuffle(self):
        random.shuffle(self.deck)
        
    def __len__(self):
        return len(self.deck)

# %%
# PLAYER CLASS

# THIS CLASS HAS ALL THE INFORMATION ABOUT THE CARDS A PLAYER IS HOLDING

# %%
class Player:
    
    def __init__(self,name):
        self.cards = []
        self.name = name
        
        
    def add(self,new_cards):
        self.cards.extend(new_cards)
        
        
    def move(self):
        return self.cards.pop(0)
    
    def __str__(self):
        ans =''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return  self.name +" has the following cards:" +ans
    
    def __len__(self):
        return len(self.cards)

# %%
class Table:
    
    def __init__(self):
        self.cards = []
        
        
    def add(self,new_cards):
        self.cards.append(new_cards)
        
    def remove(self):
        self.cards = []
        
    def __str__(self):
        ans = ''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
            
        return 'Table has these following cards : ' + ans
    
    def __len__(self):
        return len(self.cards)

# %%
# This function take the input names of the players
def player_name():
    user_1 = input('hi please enter your name')
    print('Hi', user_1)
    user_2 = input('hi please enter your name')
    print('Hello', user_2)
    return (user_1,user_2)

# %%
#Intialize a deck of cards

deck = Deck()
deck.shuffle()
len(deck)
# Out:
# 52

# %%
#make new players

name_1,name_2 = player_name()
user_1 = Player(name_1)
user_2 = Player(name_2)
# Out:
# hi please enter your nameSwaraj
# Hi Swaraj
# hi please enter your nameHimanshu
# Hello Himanshu

# %%
user_1.add(deck.deck[0:26])
user_2.add(deck.deck[26:52])

# %%
print(user_1)
# Out:
# Swaraj has the following cards:
# Seven of Hearts
# Ten of Diamonds
# Four of Spades
# Five of Hearts
# Five of Clubs
# Five of Diamonds
# King of Diamonds
# Queen of Clubs
# Six of Diamonds
# Eight of Spades
# King of Hearts
# Ten of Clubs
# Seven of Clubs
# Jack of Spades
# Nine of Clubs
# Three of Diamonds
# Two of Spades
# Nine of Spades
# Jack of Clubs
# Queen of Spades
# Three of Hearts
# Ten of Spades
# Queen of Diamonds
# Four of Hearts
# Ten of Hearts
# Seven of Spades

# %%
print(user_2)
# Out:
# Himanshu has the following cards:
# Four of Clubs
# Three of Clubs
# Two of Clubs
# Nine of Diamonds
# Two of Diamonds
# Ace of Clubs
# King of Spades
# Jack of Hearts
# Six of Clubs
# King of Clubs
# Ace of Spades
# Ace of Diamonds
# Nine of Hearts
# Two of Hearts
# Queen of Hearts
# Jack of Diamonds
# Three of Spades
# Eight of Diamonds
# Six of Hearts
# Ace of Hearts
# Five of Spades
# Eight of Hearts
# Six of Spades
# Seven of Diamonds
# Four of Diamonds
# Eight of Clubs

# %%
table = Table()

# %%
player = 1

while True:
    print('No of cards with', user_1.name,'are',len(user_1))
    print('No of cards with', user_2.name,'are',len(user_2))
    print('No of cards on the table are',len(table))
    print('\n')
    
    if player == 1:
        card = user_1.move()
        print(user_1.name,'Please press enter to move a chance. you have a card', card.__str__(), '\n')
        a = input('Press any key')
        print('Top cards on the table are','\n')
        table.add(card)
        
        print(table.cards[-1])
        
        if len(table)>1:
            print(table.cards[-2])
            
        if len(table)>1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank==table.cards[-2].rank:
                print('Wooho top two cards match', user_1.name,'Wins this move','\n')
                user_1.add(table.cards[::-1])
                table.remove()
        
        player =2
        
    else:
        card = user_2.move()
        print(user_2.name,'Please press enter to move a chance. you have a card', card.__str__(), '\n')
        a = input('Press any key')
        print('Top cards on the table are','\n')
        table.add(card)
        
        print(table.cards[-1])
        
        if len(table)>1:
            print(table.cards[-2])
            
        if len(table)>1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank==table.cards[-2].rank:
                print('Wooho top two cards match', user_2.name,'Wins this move','\n')
                user_2.add(table.cards[::-1])
                table.remove()
        
        player =1
        
    if len(user_1) == 0:
        print('Congrats',user_2.name,'Won')
        break
        
    if len(user_2)==0:
        print('Congrats',user_1.name,'Won')
        break
# Out:
# No of cards with Swaraj are 26
# No of cards with Himanshu are 26
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Hearts
#
# Press any key
# Top cards on the table are
#
# Seven of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 26
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Clubs
#
# Press any key
# Top cards on the table are
#
# Four of Clubs
# Seven of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 25
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ten of Diamonds
# Four of Clubs
# No of cards with Swaraj are 24
# No of cards with Himanshu are 25
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# Ten of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 24
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Spades
#
# Press any key
# Top cards on the table are
#
# Four of Spades
# Three of Clubs
# No of cards with Swaraj are 23
# No of cards with Himanshu are 24
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Clubs
#
# Press any key
# Top cards on the table are
#
# Two of Clubs
# Four of Spades
# No of cards with Swaraj are 23
# No of cards with Himanshu are 23
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Hearts
#
# Press any key
# Top cards on the table are
#
# Five of Hearts
# Two of Clubs
# No of cards with Swaraj are 22
# No of cards with Himanshu are 23
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Diamonds
#
# Press any key
# Top cards on the table are
#
# Nine of Diamonds
# Five of Hearts
# No of cards with Swaraj are 22
# No of cards with Himanshu are 22
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Clubs
#
# Press any key
# Top cards on the table are
#
# Five of Clubs
# Nine of Diamonds
# No of cards with Swaraj are 21
# No of cards with Himanshu are 22
# No of cards on the table are 9
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# Five of Clubs
# No of cards with Swaraj are 21
# No of cards with Himanshu are 21
# No of cards on the table are 10
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Two of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 31
# No of cards with Himanshu are 21
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Clubs
#
# Press any key
# Top cards on the table are
#
# Ace of Clubs
# No of cards with Swaraj are 31
# No of cards with Himanshu are 20
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card King of Diamonds
#
# Press any key
# Top cards on the table are
#
# King of Diamonds
# Ace of Clubs
# No of cards with Swaraj are 30
# No of cards with Himanshu are 20
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card King of Spades
#
# Press any key
# Top cards on the table are
#
# King of Spades
# King of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 30
# No of cards with Himanshu are 22
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# No of cards with Swaraj are 29
# No of cards with Himanshu are 22
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Hearts
#
# Press any key
# Top cards on the table are
#
# Jack of Hearts
# Queen of Clubs
# No of cards with Swaraj are 29
# No of cards with Himanshu are 21
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Diamonds
#
# Press any key
# Top cards on the table are
#
# Six of Diamonds
# Jack of Hearts
# No of cards with Swaraj are 28
# No of cards with Himanshu are 21
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Clubs
#
# Press any key
# Top cards on the table are
#
# Six of Clubs
# Six of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 28
# No of cards with Himanshu are 24
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Spades
#
# Press any key
# Top cards on the table are
#
# Eight of Spades
# No of cards with Swaraj are 27
# No of cards with Himanshu are 24
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card King of Clubs
#
# Press any key
# Top cards on the table are
#
# King of Clubs
# Eight of Spades
# No of cards with Swaraj are 27
# No of cards with Himanshu are 23
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card King of Hearts
#
# Press any key
# Top cards on the table are
#
# King of Hearts
# King of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 29
# No of cards with Himanshu are 23
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Spades
#
# Press any key
# Top cards on the table are
#
# Ace of Spades
# No of cards with Swaraj are 29
# No of cards with Himanshu are 22
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Clubs
#
# Press any key
# Top cards on the table are
#
# Ten of Clubs
# Ace of Spades
# No of cards with Swaraj are 28
# No of cards with Himanshu are 22
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ace of Diamonds
# Ten of Clubs
# No of cards with Swaraj are 28
# No of cards with Himanshu are 21
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Clubs
#
# Press any key
# Top cards on the table are
#
# Seven of Clubs
# Ace of Diamonds
# No of cards with Swaraj are 27
# No of cards with Himanshu are 21
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# Seven of Clubs
# No of cards with Swaraj are 27
# No of cards with Himanshu are 20
# No of cards on the table are 5
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Spades
#
# Press any key
# Top cards on the table are
#
# Jack of Spades
# Nine of Hearts
# No of cards with Swaraj are 26
# No of cards with Himanshu are 20
# No of cards on the table are 6
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# Jack of Spades
# No of cards with Swaraj are 26
# No of cards with Himanshu are 19
# No of cards on the table are 7
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Clubs
#
# Press any key
# Top cards on the table are
#
# Nine of Clubs
# Two of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 19
# No of cards on the table are 8
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Hearts
#
# Press any key
# Top cards on the table are
#
# Queen of Hearts
# Nine of Clubs
# No of cards with Swaraj are 25
# No of cards with Himanshu are 18
# No of cards on the table are 9
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Diamonds
#
# Press any key
# Top cards on the table are
#
# Three of Diamonds
# Queen of Hearts
# No of cards with Swaraj are 24
# No of cards with Himanshu are 18
# No of cards on the table are 10
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Diamonds
#
# Press any key
# Top cards on the table are
#
# Jack of Diamonds
# Three of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 24
# No of cards with Himanshu are 28
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Spades
# Press any key
# Top cards on the table are
#
# Two of Spades
# No of cards with Swaraj are 23
# No of cards with Himanshu are 28
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Spades
#
# Press any key
# Top cards on the table are
#
# Three of Spades
# Two of Spades
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 23
# No of cards with Himanshu are 29
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Press any key
# Top cards on the table are
#
# Nine of Spades
# No of cards with Swaraj are 22
# No of cards with Himanshu are 29
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Diamonds
#
# Press any key
# Top cards on the table are
#
# Eight of Diamonds
# Nine of Spades
# No of cards with Swaraj are 22
# No of cards with Himanshu are 28
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Clubs
#
# Press any key
# Top cards on the table are
#
# Jack of Clubs
# Eight of Diamonds
# No of cards with Swaraj are 21
# No of cards with Himanshu are 28
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Jack of Clubs
# No of cards with Swaraj are 21
# No of cards with Himanshu are 27
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Spades
#
# Press any key
# Top cards on the table are
#
# Queen of Spades
# Six of Hearts
# No of cards with Swaraj are 20
# No of cards with Himanshu are 27
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Hearts
#
# Press any key
# Top cards on the table are
#
# Ace of Hearts
# Queen of Spades
# No of cards with Swaraj are 20
# No of cards with Himanshu are 26
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Hearts
#
# Press any key
# Top cards on the table are
#
# Three of Hearts
# Ace of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 26
# No of cards with Himanshu are 26
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Top cards on the table are
#
# Five of Spades
# No of cards with Swaraj are 26
# No of cards with Himanshu are 25
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Spades
#
# Press any key
# Top cards on the table are
#
# Ten of Spades
# Five of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 27
# No of cards with Himanshu are 25
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Hearts
#
# Press any key
# Top cards on the table are
#
# Eight of Hearts
# No of cards with Swaraj are 27
# No of cards with Himanshu are 24
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Diamonds
#
# Press any key
# Top cards on the table are
#
# Queen of Diamonds
# Eight of Hearts
# No of cards with Swaraj are 26
# No of cards with Himanshu are 24
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Spades
#
# Press any key
# Top cards on the table are
#
# Six of Spades
# Queen of Diamonds
# No of cards with Swaraj are 26
# No of cards with Himanshu are 23
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Hearts
#
# Press any key
# Top cards on the table are
#
# Four of Hearts
# Six of Spades
# No of cards with Swaraj are 25
# No of cards with Himanshu are 23
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Diamonds
#
# Press any key
# Top cards on the table are
#
# Seven of Diamonds
# Four of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 22
# No of cards on the table are 5
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Hearts
#
# Press any key
# Top cards on the table are
#
# Ten of Hearts
# Seven of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 22
# No of cards on the table are 6
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Diamonds
#
# Press any key
# Top cards on the table are
#
# Four of Diamonds
# Ten of Hearts
# No of cards with Swaraj are 24
# No of cards with Himanshu are 21
# No of cards on the table are 7
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Spades
#
# Press any key
# Top cards on the table are
#
# Seven of Spades
# Four of Diamonds
# No of cards with Swaraj are 23
# No of cards with Himanshu are 21
# No of cards on the table are 8
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Clubs
#
# Press any key
# Top cards on the table are
#
# Eight of Clubs
# Seven of Spades
# No of cards with Swaraj are 23
# No of cards with Himanshu are 20
# No of cards on the table are 9
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Eight of Clubs
# No of cards with Swaraj are 22
# No of cards with Himanshu are 20
# No of cards on the table are 10
#
#
# Himanshu Please press enter to move a chance. you have a card King of Spades
#
# Press any key
# Top cards on the table are
#
# King of Spades
# Five of Diamonds
# No of cards with Swaraj are 22
# No of cards with Himanshu are 19
# No of cards on the table are 11
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# King of Spades
# No of cards with Swaraj are 21
# No of cards with Himanshu are 19
# No of cards on the table are 12
#
#
# Himanshu Please press enter to move a chance. you have a card King of Diamonds
#
# Press any key
# Top cards on the table are
#
# King of Diamonds
# Two of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 21
# No of cards with Himanshu are 31
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Clubs
#
# Press any key
# Top cards on the table are
#
# Five of Clubs
# No of cards with Swaraj are 20
# No of cards with Himanshu are 31
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Clubs
#
# Press any key
# Top cards on the table are
#
# Ace of Clubs
# Five of Clubs
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 20
# No of cards with Himanshu are 32
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Diamonds
#
# Press any key
# Top cards on the table are
#
# Nine of Diamonds
# No of cards with Swaraj are 19
# No of cards with Himanshu are 32
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Clubs
#
# Press any key
# Top cards on the table are
#
# Six of Clubs
# Nine of Diamonds
# No of cards with Swaraj are 19
# No of cards with Himanshu are 31
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Hearts
#
# Press any key
# Top cards on the table are
#
# Five of Hearts
# Six of Clubs
# No of cards with Swaraj are 18
# No of cards with Himanshu are 31
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Diamonds
#
# Press any key
# Top cards on the table are
#
# Six of Diamonds
# Five of Hearts
# No of cards with Swaraj are 18
# No of cards with Himanshu are 30
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Clubs
#
# Press any key
# Top cards on the table are
#
# Two of Clubs
# Six of Diamonds
# No of cards with Swaraj are 17
# No of cards with Himanshu are 30
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Hearts
#
# Press any key
# Top cards on the table are
#
# Jack of Hearts
# Two of Clubs
# No of cards with Swaraj are 17
# No of cards with Himanshu are 29
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Spades
#
# Press any key
# Top cards on the table are
#
# Four of Spades
# Jack of Hearts
# No of cards with Swaraj are 16
# No of cards with Himanshu are 29
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Clubs
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# Four of Spades
# No of cards with Swaraj are 16
# No of cards with Himanshu are 28
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# Queen of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 24
# No of cards with Himanshu are 28
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Diamonds
#
# Press any key
# Top cards on the table are
#
# Jack of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 27
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ten of Diamonds
# Jack of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 25
# No of cards with Himanshu are 27
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Diamonds
#
# Press any key
# Top cards on the table are
#
# Three of Diamonds
# No of cards with Swaraj are 25
# No of cards with Himanshu are 26
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Clubs
#
# Press any key
# Top cards on the table are
#
# Four of Clubs
# Three of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 26
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Hearts
#
# Press any key
# Top cards on the table are
#
# Queen of Hearts
# Four of Clubs
# No of cards with Swaraj are 24
# No of cards with Himanshu are 25
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Hearts
#
# Press any key
# Top cards on the table are
#
# Seven of Hearts
# Queen of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 27
# No of cards with Himanshu are 25
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Clubs
#
# Press any key
# Top cards on the table are
#
# Nine of Clubs
# No of cards with Swaraj are 27
# No of cards with Himanshu are 24
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card King of Hearts
#
# Press any key
# Top cards on the table are
#
# King of Hearts
# Nine of Clubs
# No of cards with Swaraj are 26
# No of cards with Himanshu are 24
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# King of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 26
# No of cards with Himanshu are 26
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card King of Clubs
#
# Press any key
# Top cards on the table are
#
# King of Clubs
# No of cards with Swaraj are 25
# No of cards with Himanshu are 26
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Spades
#
# Press any key
# Top cards on the table are
#
# Jack of Spades
# King of Clubs
# No of cards with Swaraj are 25
# No of cards with Himanshu are 25
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Spades
#
# Press any key
# Top cards on the table are
#
# Eight of Spades
# Jack of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 27
# No of cards with Himanshu are 25
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# No of cards with Swaraj are 27
# No of cards with Himanshu are 24
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Hearts
#
# Press any key
# Top cards on the table are
#
# Three of Hearts
# Nine of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 28
# No of cards with Himanshu are 24
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Clubs
#
# Press any key
# Top cards on the table are
#
# Seven of Clubs
# No of cards with Swaraj are 28
# No of cards with Himanshu are 23
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ace of Hearts
#
# Press any key
# Top cards on the table are
#
# Ace of Hearts
# Seven of Clubs
# No of cards with Swaraj are 27
# No of cards with Himanshu are 23
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ace of Diamonds
# Ace of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 27
# No of cards with Himanshu are 25
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Spades
#
# Press any key
# Top cards on the table are
#
# Queen of Spades
# No of cards with Swaraj are 26
# No of cards with Himanshu are 25
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Clubs
#
# Press any key
# Top cards on the table are
#
# Ten of Clubs
# Queen of Spades
# No of cards with Swaraj are 26
# No of cards with Himanshu are 24
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Ten of Clubs
# No of cards with Swaraj are 25
# No of cards with Himanshu are 24
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Spades
#
# Press any key
# Top cards on the table are
#
# Ace of Spades
# Six of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 23
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Clubs
#
# Press any key
# Top cards on the table are
#
# Jack of Clubs
# Ace of Spades
# No of cards with Swaraj are 24
# No of cards with Himanshu are 23
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Spades
#
# Press any key
# Top cards on the table are
#
# Three of Spades
# Jack of Clubs
# No of cards with Swaraj are 24
# No of cards with Himanshu are 22
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Diamonds
#
# Press any key
# Top cards on the table are
#
# Eight of Diamonds
# Three of Spades
# No of cards with Swaraj are 23
# No of cards with Himanshu are 22
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Spades
#
# Press any key
# Top cards on the table are
#
# Two of Spades
# Eight of Diamonds
# No of cards with Swaraj are 23
# No of cards with Himanshu are 21
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Press any key
# Top cards on the table are
#
# Nine of Spades
# Two of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 31
# No of cards with Himanshu are 21
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card King of Diamonds
#
# Press any key
# Top cards on the table are
#
# King of Diamonds
# No of cards with Swaraj are 31
# No of cards with Himanshu are 20
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Spades
#
# Press any key
# Top cards on the table are
#
# Ten of Spades
# King of Diamonds
# No of cards with Swaraj are 30
# No of cards with Himanshu are 20
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# Ten of Spades
# No of cards with Swaraj are 30
# No of cards with Himanshu are 19
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Top cards on the table are
#
# Five of Spades
# Two of Diamonds
# No of cards with Swaraj are 29
# No of cards with Himanshu are 19
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card King of Spades
# Press any key
# Top cards on the table are
#
# King of Spades
# Five of Spades
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 29
# No of cards with Himanshu are 23
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# No of cards with Swaraj are 28
# No of cards with Himanshu are 23
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Three of Clubs
# No of cards with Swaraj are 28
# No of cards with Himanshu are 22
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# Five of Diamonds
# No of cards with Swaraj are 27
# No of cards with Himanshu are 22
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Clubs
#
# Press any key
# Top cards on the table are
#
# Eight of Clubs
# Queen of Clubs
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 27
# No of cards with Himanshu are 25
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Spades
#
# Press any key
# Top cards on the table are
#
# Four of Spades
# No of cards with Swaraj are 26
# No of cards with Himanshu are 25
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Spades
#
# Press any key
# Top cards on the table are
#
# Seven of Spades
# Four of Spades
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 26
# No of cards with Himanshu are 26
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Hearts
#
# Press any key
# Top cards on the table are
#
# Jack of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 26
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Diamonds
#
# Press any key
# Top cards on the table are
#
# Four of Diamonds
# Jack of Hearts
# No of cards with Swaraj are 25
# No of cards with Himanshu are 25
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Clubs
#
# Press any key
# Top cards on the table are
#
# Two of Clubs
# Four of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 25
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Hearts
#
# Press any key
# Top cards on the table are
#
# Ten of Hearts
# Two of Clubs
# No of cards with Swaraj are 24
# No of cards with Himanshu are 24
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Diamonds
#
# Press any key
# Top cards on the table are
#
# Six of Diamonds
# Ten of Hearts
# No of cards with Swaraj are 23
# No of cards with Himanshu are 24
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Diamonds
#
# Press any key
# Top cards on the table are
#
# Seven of Diamonds
# Six of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 23
# No of cards with Himanshu are 29
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Hearts
#
# Press any key
# Top cards on the table are
#
# Five of Hearts
# No of cards with Swaraj are 22
# No of cards with Himanshu are 29
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Hearts
#
# Press any key
# Top cards on the table are
#
# Four of Hearts
# Five of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 22
# No of cards with Himanshu are 30
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Clubs
#
# Press any key
# Top cards on the table are
#
# Six of Clubs
# No of cards with Swaraj are 21
# No of cards with Himanshu are 30
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Spades
#
# Press any key
# Top cards on the table are
#
# Six of Spades
# Six of Clubs
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 21
# No of cards with Himanshu are 31
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Diamonds
#
# Press any key
# Top cards on the table are
#
# Nine of Diamonds
# No of cards with Swaraj are 20
# No of cards with Himanshu are 31
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Diamonds
#
# Press any key
# Top cards on the table are
#
# Queen of Diamonds
# Nine of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 20
# No of cards with Himanshu are 32
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ten of Diamonds
# No of cards with Swaraj are 19
# No of cards with Himanshu are 32
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Hearts
#
# Press any key
# Top cards on the table are
#
# Eight of Hearts
# Ten of Diamonds
# No of cards with Swaraj are 19
# No of cards with Himanshu are 31
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Diamonds
#
# Press any key
# Top cards on the table are
#
# Jack of Diamonds
# Eight of Hearts
# No of cards with Swaraj are 18
# No of cards with Himanshu are 31
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Clubs
#
# Press any key
# Top cards on the table are
#
# Ace of Clubs
# Jack of Diamonds
# No of cards with Swaraj are 18
# No of cards with Himanshu are 30
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Hearts
#
# Press any key
# Press any key
# Top cards on the table are
#
# Seven of Hearts
# Ace of Clubs
# No of cards with Swaraj are 17
# No of cards with Himanshu are 30
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Clubs
#
# Top cards on the table are
#
# Five of Clubs
# Seven of Hearts
# No of cards with Swaraj are 17
# No of cards with Himanshu are 29
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Hearts
#
# Press any key
# Top cards on the table are
#
# Queen of Hearts
# Five of Clubs
# No of cards with Swaraj are 16
# No of cards with Himanshu are 29
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# Queen of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 16
# No of cards with Himanshu are 36
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Clubs
#
# Press any key
# Top cards on the table are
#
# Four of Clubs
# No of cards with Swaraj are 15
# No of cards with Himanshu are 36
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card King of Hearts
#
# Press any key
# Press any key
# Top cards on the table are
#
# King of Hearts
# Four of Clubs
# No of cards with Swaraj are 15
# No of cards with Himanshu are 35
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Diamonds
#
# Top cards on the table are
#
# Three of Diamonds
# King of Hearts
# No of cards with Swaraj are 14
# No of cards with Himanshu are 35
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Clubs
#
# Press any key
# Top cards on the table are
#
# Nine of Clubs
# Three of Diamonds
# No of cards with Swaraj are 14
# No of cards with Himanshu are 34
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Spades
#
# Press any key
# Top cards on the table are
#
# Eight of Spades
# Nine of Clubs
# No of cards with Swaraj are 13
# No of cards with Himanshu are 34
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Diamonds
# Press any key
# Press any key
# Top cards on the table are
#
# Ace of Diamonds
# Eight of Spades
# No of cards with Swaraj are 13
# No of cards with Himanshu are 33
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Spades
#
# Top cards on the table are
#
# Jack of Spades
# Ace of Diamonds
# No of cards with Swaraj are 12
# No of cards with Himanshu are 33
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Hearts
#
# Press any key
# Top cards on the table are
#
# Ace of Hearts
# Jack of Spades
# No of cards with Swaraj are 12
# No of cards with Himanshu are 32
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card King of Clubs
#
# Press any key
# Press any key
# Top cards on the table are
#
# King of Clubs
# Ace of Hearts
# No of cards with Swaraj are 11
# No of cards with Himanshu are 32
# No of cards on the table are 9
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Clubs
#
# Top cards on the table are
#
# Seven of Clubs
# King of Clubs
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 11
# No of cards with Himanshu are 41
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Hearts
#
# Press any key
# Press any key
# Top cards on the table are
#
# Three of Hearts
# No of cards with Swaraj are 10
# No of cards with Himanshu are 41
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card King of Spades
#
# Top cards on the table are
#
# King of Spades
# Three of Hearts
# No of cards with Swaraj are 10
# No of cards with Himanshu are 40
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# King of Spades
# No of cards with Swaraj are 9
# No of cards with Himanshu are 40
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Press any key
# Top cards on the table are
#
# Five of Spades
# Nine of Hearts
# No of cards with Swaraj are 9
# No of cards with Himanshu are 39
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Top cards on the table are
#
# Nine of Spades
# Five of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 13
# No of cards with Himanshu are 39
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# No of cards with Swaraj are 13
# No of cards with Himanshu are 38
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Spades
#
# Press any key
# Top cards on the table are
#
# Two of Spades
# Two of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 14
# No of cards with Himanshu are 38
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Spades
#
# Press any key
# Top cards on the table are
#
# Ten of Spades
# No of cards with Swaraj are 14
# No of cards with Himanshu are 37
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Diamonds
#
# Press any key
# Top cards on the table are
#
# Eight of Diamonds
# Ten of Spades
# No of cards with Swaraj are 13
# No of cards with Himanshu are 37
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card King of Diamonds
#
# Press any key
# Top cards on the table are
#
# King of Diamonds
# Eight of Diamonds
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 13
# No of cards with Himanshu are 39
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Spades
#
# Press any key
# Top cards on the table are
#
# Three of Spades
# No of cards with Swaraj are 12
# No of cards with Himanshu are 39
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Clubs
#
# Press any key
# Top cards on the table are
#
# Eight of Clubs
# Three of Spades
# No of cards with Swaraj are 12
# No of cards with Himanshu are 38
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Clubs
#
# Press any key
# Top cards on the table are
#
# Jack of Clubs
# Eight of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 14
# No of cards with Himanshu are 38
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# No of cards with Swaraj are 14
# No of cards with Himanshu are 37
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ace of Spades
#
# Press any key
# Top cards on the table are
#
# Ace of Spades
# Queen of Clubs
# No of cards with Swaraj are 13
# No of cards with Himanshu are 37
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Ace of Spades
# No of cards with Swaraj are 13
# No of cards with Himanshu are 36
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Five of Diamonds
# No of cards with Swaraj are 12
# No of cards with Himanshu are 36
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# Six of Hearts
# No of cards with Swaraj are 12
# No of cards with Himanshu are 35
# No of cards on the table are 5
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Clubs
#
# Press any key
# Top cards on the table are
#
# Ten of Clubs
# Three of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 17
# No of cards with Himanshu are 35
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Spades
#
# Press any key
# Top cards on the table are
#
# Seven of Spades
# No of cards with Swaraj are 17
# No of cards with Himanshu are 34
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Spades
#
# Press any key
# Top cards on the table are
#
# Queen of Spades
# Seven of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 18
# No of cards with Himanshu are 34
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Spades
#
# Press any key
# Top cards on the table are
#
# Four of Spades
# No of cards with Swaraj are 18
# No of cards with Himanshu are 33
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Press any key
# Top cards on the table are
#
# Nine of Spades
# Four of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 19
# No of cards with Himanshu are 33
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Diamonds
#
# Press any key
# Top cards on the table are
#
# Seven of Diamonds
# No of cards with Swaraj are 19
# No of cards with Himanshu are 32
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Top cards on the table are
#
# Five of Spades
# Seven of Diamonds
# No of cards with Swaraj are 18
# No of cards with Himanshu are 32
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Diamonds
#
# Press any key
# Top cards on the table are
#
# Six of Diamonds
# Five of Spades
# No of cards with Swaraj are 18
# No of cards with Himanshu are 31
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# Six of Diamonds
# No of cards with Swaraj are 17
# No of cards with Himanshu are 31
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Hearts
# Press any key
# Top cards on the table are
#
# Ten of Hearts
# Nine of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 17
# No of cards with Himanshu are 35
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card King of Spades
#
# Press any key
# Top cards on the table are
#
# King of Spades
# No of cards with Swaraj are 16
# No of cards with Himanshu are 35
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Clubs
#
# Press any key
# Top cards on the table are
#
# Two of Clubs
# King of Spades
# No of cards with Swaraj are 16
# No of cards with Himanshu are 34
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Hearts
#
# Press any key
# Top cards on the table are
#
# Three of Hearts
# Two of Clubs
# No of cards with Swaraj are 15
# No of cards with Himanshu are 34
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Diamonds
#
# Press any key
# Top cards on the table are
#
# Four of Diamonds
# Three of Hearts
# No of cards with Swaraj are 15
# No of cards with Himanshu are 33
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Spades
#
# Press any key
# Top cards on the table are
#
# Two of Spades
# Four of Diamonds
# No of cards with Swaraj are 14
# No of cards with Himanshu are 33
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Hearts
#
# Press any key
# Top cards on the table are
#
# Jack of Hearts
# Two of Spades
# No of cards with Swaraj are 14
# No of cards with Himanshu are 32
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# Jack of Hearts
# No of cards with Swaraj are 13
# No of cards with Himanshu are 32
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Hearts
#
# Press any key
# Top cards on the table are
#
# Four of Hearts
# Two of Diamonds
# No of cards with Swaraj are 13
# No of cards with Himanshu are 31
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Clubs
#
# Press any key
# Top cards on the table are
#
# Jack of Clubs
# Four of Hearts
# No of cards with Swaraj are 12
# No of cards with Himanshu are 31
# No of cards on the table are 9
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Hearts
#
# Press any key
# Top cards on the table are
#
# Five of Hearts
# Jack of Clubs
# No of cards with Swaraj are 12
# No of cards with Himanshu are 30
# No of cards on the table are 10
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Clubs
#
# Press any key
# Top cards on the table are
#
# Eight of Clubs
# Five of Hearts
# No of cards with Swaraj are 11
# No of cards with Himanshu are 30
# No of cards on the table are 11
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Spades
#
# Press any key
# Top cards on the table are
#
# Six of Spades
# Eight of Clubs
# No of cards with Swaraj are 11
# No of cards with Himanshu are 29
# No of cards on the table are 12
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Spades
#
# Press any key
# Top cards on the table are
#
# Three of Spades
# Six of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 23
# No of cards with Himanshu are 29
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Clubs
#
# Press any key
# Top cards on the table are
#
# Six of Clubs
# No of cards with Swaraj are 23
# No of cards with Himanshu are 28
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Clubs
#
# Press any key
# Top cards on the table are
#
# Ten of Clubs
# Six of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 24
# No of cards with Himanshu are 28
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Diamonds
#
# Press any key
# Top cards on the table are
#
# Queen of Diamonds
# No of cards with Swaraj are 24
# No of cards with Himanshu are 27
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# Queen of Diamonds
# No of cards with Swaraj are 23
# No of cards with Himanshu are 27
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Diamonds
#
# Press any key
# Top cards on the table are
#
# Nine of Diamonds
# Three of Clubs
# No of cards with Swaraj are 23
# No of cards with Himanshu are 26
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Nine of Diamonds
# No of cards with Swaraj are 22
# No of cards with Himanshu are 26
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# Six of Hearts
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 22
# No of cards with Himanshu are 30
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# No of cards with Swaraj are 21
# No of cards with Himanshu are 30
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Hearts
#
# Press any key
# Top cards on the table are
#
# Queen of Hearts
# Five of Diamonds
# No of cards with Swaraj are 21
# No of cards with Himanshu are 29
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Ace of Spades
#
# Press any key
# Top cards on the table are
#
# Ace of Spades
# Queen of Hearts
# No of cards with Swaraj are 20
# No of cards with Himanshu are 29
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Clubs
#
# Press any key
# Top cards on the table are
#
# Five of Clubs
# Ace of Spades
# No of cards with Swaraj are 20
# No of cards with Himanshu are 28
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# Five of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 24
# No of cards with Himanshu are 28
# No of cards on the table are 0
#
#
# ...
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Hearts
#
# Press any key
# Top cards on the table are
#
# Eight of Hearts
# No of cards with Swaraj are 17
# No of cards with Himanshu are 34
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# Eight of Hearts
# No of cards with Swaraj are 17
# No of cards with Himanshu are 33
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Spades
#
# Press any key
# Top cards on the table are
#
# Queen of Spades
# Queen of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 19
# No of cards with Himanshu are 33
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# No of cards with Swaraj are 19
# No of cards with Himanshu are 32
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Spades
#
# Press any key
# Top cards on the table are
#
# Eight of Spades
# Nine of Hearts
# No of cards with Swaraj are 18
# No of cards with Himanshu are 32
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Clubs
# Press any key
# Top cards on the table are
#
# Six of Clubs
# Eight of Spades
# No of cards with Swaraj are 18
# No of cards with Himanshu are 31
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Ace of Clubs
#
# Press any key
# Top cards on the table are
#
# Ace of Clubs
# Six of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 21
# No of cards with Himanshu are 31
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# No of cards with Swaraj are 21
# No of cards with Himanshu are 30
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# Two of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 22
# No of cards with Himanshu are 30
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Hearts
#
# Press any key
# Top cards on the table are
#
# Queen of Hearts
# No of cards with Swaraj are 22
# No of cards with Himanshu are 29
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Spades
#
# Press any key
# Top cards on the table are
#
# Seven of Spades
# Queen of Hearts
# No of cards with Swaraj are 21
# No of cards with Himanshu are 29
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Diamonds
#
# Press any key
# Top cards on the table are
#
# Seven of Diamonds
# Seven of Spades
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 21
# No of cards with Himanshu are 31
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Clubs
#
# Press any key
# Top cards on the table are
#
# Nine of Clubs
# No of cards with Swaraj are 20
# No of cards with Himanshu are 31
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Spades
#
# Press any key
# Top cards on the table are
#
# Ace of Spades
# Nine of Clubs
# No of cards with Swaraj are 20
# No of cards with Himanshu are 30
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Seven of Hearts
#
# Press any key
# Top cards on the table are
#
# Seven of Hearts
# Ace of Spades
# No of cards with Swaraj are 19
# No of cards with Himanshu are 30
# No of cards on the table are 3
#
#
# Himanshu Please press enter to move a chance. you have a card Three of Clubs
#
# Press any key
# Top cards on the table are
#
# Three of Clubs
# Seven of Hearts
# No of cards with Swaraj are 19
# No of cards with Himanshu are 29
# No of cards on the table are 4
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Hearts
#
# Press any key
# Top cards on the table are
#
# Four of Hearts
# Three of Clubs
# No of cards with Swaraj are 18
# No of cards with Himanshu are 29
# No of cards on the table are 5
#
#
# Himanshu Please press enter to move a chance. you have a card King of Clubs
#
# Press any key
# Top cards on the table are
#
# King of Clubs
# Four of Hearts
# No of cards with Swaraj are 18
# No of cards with Himanshu are 28
# No of cards on the table are 6
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Spades
#
# Press any key
# Top cards on the table are
#
# Three of Spades
# King of Clubs
# No of cards with Swaraj are 17
# No of cards with Himanshu are 28
# No of cards on the table are 7
#
#
# Himanshu Please press enter to move a chance. you have a card Nine of Diamonds
#
# Press any key
# Top cards on the table are
#
# Nine of Diamonds
# Three of Spades
# No of cards with Swaraj are 17
# No of cards with Himanshu are 27
# No of cards on the table are 8
#
#
# Swaraj Please press enter to move a chance. you have a card Three of Hearts
#
# Press any key
# Top cards on the table are
#
# Three of Hearts
# Nine of Diamonds
# No of cards with Swaraj are 16
# No of cards with Himanshu are 27
# No of cards on the table are 9
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Clubs
#
# Press any key
# Top cards on the table are
#
# Eight of Clubs
# Three of Hearts
# No of cards with Swaraj are 16
# No of cards with Himanshu are 26
# No of cards on the table are 10
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Diamonds
#
# Press any key
# Top cards on the table are
#
# Four of Diamonds
# Eight of Clubs
# No of cards with Swaraj are 15
# No of cards with Himanshu are 26
# No of cards on the table are 11
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Four of Diamonds
# No of cards with Swaraj are 15
# No of cards with Himanshu are 25
# No of cards on the table are 12
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Press any key
# Top cards on the table are
#
# Nine of Spades
# Six of Hearts
# No of cards with Swaraj are 14
# No of cards with Himanshu are 25
# No of cards on the table are 13
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Nine of Spades
# No of cards with Swaraj are 14
# No of cards with Himanshu are 24
# No of cards on the table are 14
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Top cards on the table are
#
# Five of Spades
# Five of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 28
# No of cards with Himanshu are 24
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Clubs
#
# Press any key
# Top cards on the table are
#
# Four of Clubs
# No of cards with Swaraj are 28
# No of cards with Himanshu are 23
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Hearts
#
# Press any key
# Top cards on the table are
#
# Jack of Hearts
# Four of Clubs
# No of cards with Swaraj are 27
# No of cards with Himanshu are 23
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Seven of Clubs
#
# Press any key
# Top cards on the table are
#
# Seven of Clubs
# Jack of Hearts
# No of cards with Swaraj are 27
# No of cards with Himanshu are 22
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Clubs
#
# Press any key
# Top cards on the table are
#
# Ten of Clubs
# Seven of Clubs
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 30
# No of cards with Himanshu are 22
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Queen of Diamonds
#
# Press any key
# Top cards on the table are
#
# Queen of Diamonds
# No of cards with Swaraj are 30
# No of cards with Himanshu are 21
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Jack of Diamonds
#
# Press any key
# Top cards on the table are
#
# Jack of Diamonds
# Queen of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 31
# No of cards with Himanshu are 21
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Six of Spades
#
# Press any key
# Top cards on the table are
#
# Six of Spades
# No of cards with Swaraj are 31
# No of cards with Himanshu are 20
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ten of Hearts
#
# Press any key
# Top cards on the table are
#
# Ten of Hearts
# Six of Spades
# No of cards with Swaraj are 30
# No of cards with Himanshu are 20
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Spades
#
# Press any key
# Top cards on the table are
#
# Two of Spades
# Ten of Hearts
# No of cards with Swaraj are 30
# No of cards with Himanshu are 19
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Spades
#
# Press any key
# Top cards on the table are
#
# Queen of Spades
# Two of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 33
# No of cards with Himanshu are 19
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Four of Spades
# Press any key
# Top cards on the table are
#
# Four of Spades
# No of cards with Swaraj are 33
# No of cards with Himanshu are 18
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Queen of Clubs
#
# Press any key
# Top cards on the table are
#
# Queen of Clubs
# Four of Spades
# No of cards with Swaraj are 32
# No of cards with Himanshu are 18
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card King of Hearts
#
# Press any key
# Top cards on the table are
#
# King of Hearts
# Queen of Clubs
# No of cards with Swaraj are 32
# No of cards with Himanshu are 17
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Hearts
#
# Press any key
# Top cards on the table are
#
# Eight of Hearts
# King of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 35
# No of cards with Himanshu are 17
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card King of Diamonds
#
# Press any key
# Top cards on the table are
#
# King of Diamonds
# No of cards with Swaraj are 35
# No of cards with Himanshu are 16
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Ace of Clubs
#
# Press any key
# Top cards on the table are
#
# Ace of Clubs
# King of Diamonds
# No of cards with Swaraj are 34
# No of cards with Himanshu are 16
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ten of Diamonds
# Ace of Clubs
# No of cards with Swaraj are 34
# No of cards with Himanshu are 15
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Clubs
#
# Press any key
# Top cards on the table are
#
# Six of Clubs
# Ten of Diamonds
# No of cards with Swaraj are 33
# No of cards with Himanshu are 15
# No of cards on the table are 4
#
#
# Himanshu Please press enter to move a chance. you have a card Two of Clubs
#
# Press any key
# Top cards on the table are
#
# Two of Clubs
# Six of Clubs
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 33
# No of cards with Himanshu are 19
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Eight of Spades
#
# Press any key
# Top cards on the table are
#
# Eight of Spades
# No of cards with Swaraj are 32
# No of cards with Himanshu are 19
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Spades
#
# Press any key
# Top cards on the table are
#
# Jack of Spades
# Eight of Spades
# Wooho top two cards match Himanshu Wins this move
#
# No of cards with Swaraj are 32
# No of cards with Himanshu are 20
# No of cards on the table are 0
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Hearts
#
# Press any key
# Top cards on the table are
#
# Nine of Hearts
# No of cards with Swaraj are 31
# No of cards with Himanshu are 20
# No of cards on the table are 1
#
#
# Himanshu Please press enter to move a chance. you have a card Eight of Diamonds
#
# Press any key
# Top cards on the table are
#
# Eight of Diamonds
# Nine of Hearts
# No of cards with Swaraj are 31
# No of cards with Himanshu are 19
# No of cards on the table are 2
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Diamonds
#
# Press any key
# Top cards on the table are
#
# Two of Diamonds
# Eight of Diamonds
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 33
# No of cards with Himanshu are 19
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Jack of Clubs
#
# Press any key
# Top cards on the table are
#
# Jack of Clubs
# No of cards with Swaraj are 33
# No of cards with Himanshu are 18
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Two of Hearts
#
# Press any key
# Top cards on the table are
#
# Two of Hearts
# Jack of Clubs
# No of cards with Swaraj are 32
# No of cards with Himanshu are 18
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card King of Spades
#
# Press any key
# Top cards on the table are
#
# King of Spades
# Two of Hearts
# No of cards with Swaraj are 32
# No of cards with Himanshu are 17
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Spades
#
# Press any key
# Top cards on the table are
#
# Five of Spades
# King of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 35
# No of cards with Himanshu are 17
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Hearts
#
# Press any key
# Top cards on the table are
#
# Ace of Hearts
# No of cards with Swaraj are 35
# No of cards with Himanshu are 16
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Five of Diamonds
#
# Press any key
# Top cards on the table are
#
# Five of Diamonds
# Ace of Hearts
# No of cards with Swaraj are 34
# No of cards with Himanshu are 16
# No of cards on the table are 2
#
#
# Himanshu Please press enter to move a chance. you have a card Ten of Spades
#
# Press any key
# Top cards on the table are
#
# Ten of Spades
# Five of Diamonds
# No of cards with Swaraj are 34
# No of cards with Himanshu are 15
# No of cards on the table are 3
#
#
# Swaraj Please press enter to move a chance. you have a card Nine of Spades
#
# Press any key
# Top cards on the table are
#
# Nine of Spades
# Ten of Spades
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 37
# No of cards with Himanshu are 15
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Five of Hearts
#
# Press any key
# Top cards on the table are
#
# Five of Hearts
# No of cards with Swaraj are 37
# No of cards with Himanshu are 14
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Six of Hearts
#
# Press any key
# Top cards on the table are
#
# Six of Hearts
# Five of Hearts
# Wooho top two cards match Swaraj Wins this move
#
# No of cards with Swaraj are 38
# No of cards with Himanshu are 14
# No of cards on the table are 0
#
#
# Himanshu Please press enter to move a chance. you have a card Ace of Diamonds
#
# Press any key
# Top cards on the table are
#
# Ace of Diamonds
# No of cards with Swaraj are 38
# No of cards with Himanshu are 13
# No of cards on the table are 1
#
#
# Swaraj Please press enter to move a chance. you have a card Four of Diamonds
